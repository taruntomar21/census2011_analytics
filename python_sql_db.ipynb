# %%
# !pip install mysql.connector
import mysql.connector

# %%
# !pip install pymysql

# %%
import pymysql
conn = pymysql.connect(host='campusx.c5ck4o0m492k.ap-southeast-3.rds.amazonaws.com',user='admin',password='Tarunmysql55')

# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
mycursor = conn.cursor()

# %%
mycursor.execute('CREATE DATABASE campusx')
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /tmp/ipykernel_7834/2358165266.py in <cell line: 0>()
# ----> 1 mycursor.execute('CREATE DATABASE campusx')
#       2 conn.commit()
#
# /usr/local/lib/python3.12/dist-packages/pymysql/cursors.py in execute(self, query, args)
#     151         query = self.mogrify(query, args)
#     152
# --> 153         result = self._query(query)
#     154         self._executed = query
#     155         return result
#
# /usr/local/lib/python3.12/dist-packages/pymysql/cursors.py in _query(self, q)
#     320         conn = self._get_db()
#     321         self._clear_result()
# --> 322         conn.query(q)
#     323         self._do_get_result()
#     324         return self.rowcount
#
# /usr/local/lib/python3.12/dist-packages/pymysql/connections.py in query(self, sql, unbuffered)
# ...

# %%
engine = create_engine("mysql+pymysql://admin:Tarunmysql55@campusx.c5ck4o0m492k.ap-southeast-3.rds.amazonaws.com/campusx")
# {root}:{password}@{url}/{database}

# %%
census = pd.read_csv("/content/india.csv")

# %%
census.to_sql('india', con = engine)
# Out:
# 502
